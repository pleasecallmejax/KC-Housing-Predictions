# %% [markdown]
# # Kings County Housing Prices Bakeoff
#
# Below are a list of steps that you should take while trying to complete your bake-off entry.

# %% [markdown]
# ## Step 1: Read in Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
import warnings
import folium
from sklearn.linear_model import LinearRegression
from statsmodels.formula.api import ols
import scipy.stats as stats
pd.set_option('display.max_columns', 300)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
warnings.filterwarnings("ignore")

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
org_hous_df=pd.read_csv('Data/kc_house_data_train.csv', index_col='id').drop('Unnamed: 0', axis=1)
org_hous_df.head()
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 2591820310  20141006T000000  365000.00         4       2.25         2070
# 7974200820  20140821T000000  865000.00         5       3.00         2900
# 7701450110  20140815T000000 1038000.00         4       2.50         3770
# 9522300010  20150331T000000 1490000.00         3       3.50         4560
# 9510861140  20140714T000000  711000.00         3       2.50         2550
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 2591820310      8893    2.00           0     0          4      8        2070
# 7974200820      6730    1.00           0     0          5      8        1830
# 7701450110     10893    2.00           0     2          3     11        3770
# 9522300010     14608    2.00           0     2          3     12        4560
# 9510861140      5376    2.00           0     0          3      9        2550
#
#             sqft_basement  yr_built  yr_renovated  zipcode   lat    long  \
# id
# 2591820310              0      1986             0    98058 47.44 -122.16
# 7974200820           1070      1977             0    98115 47.68 -122.28
# 7701450110              0      1997             0    98006 47.56 -122.13
# 9522300010              0      1990             0    98034 47.70 -122.23
# 9510861140              0      2004             0    98052 47.66 -122.08
#
#             sqft_living15  sqft_lot15
# id
# 2591820310           2390        7700
# 7974200820           2370        6283
# 7701450110           3710        9685
# 9522300010           4050       14226
# 9510861140           2250        4050

# %%
top5codes_price = org_hous_df.groupby("zipcode")["price"].mean().sort_values(ascending = False)[:5]
mean_price = org_hous_df.price.mean()
print(top5codes_price)
# Out:
# zipcode
# 98039   2202790.00
# 98004   1396882.89
# 98040   1183018.00
# 98112   1119457.66
# 98102    933671.47
# Name: price, dtype: float64

# %%
count_by_zip = org_hous_df.groupby("zipcode")["price"].count().sort_values(ascending = False)[:70]
count_by_zip
# Out:
# zipcode
# 98052    474
# 98115    465
# 98103    461
# 98038    455
# 98117    437
#         ...
# 98102     80
# 98010     74
# 98024     65
# 98148     43
# 98039     42
# Name: price, Length: 70, dtype: int64

# %%
mean_price_by_zip = org_hous_df.groupby("zipcode")["price"].mean().sort_values(ascending = False)[:70]
mean_price_by_zip = mean_price_by_zip.to_frame()
mean_price_by_zip['count'] = count_by_zip
mean_price_by_zip
# Out:
#              price  count
# zipcode
# 98039   2202790.00     42
# 98004   1396882.89    237
# 98040   1183018.00    229
# 98112   1119457.66    216
# 98102    933671.47     80
# ...            ...    ...
# 98001    281998.76    284
# 98148    272082.33     43
# 98032    251602.23    103
# 98168    241041.54    215
# 98002    232286.53    157
#
# [70 rows x 2 columns]

# %%
no_bedrooms = org_hous_df[org_hous_df['bedrooms'] == 0]['price']
no_bathrooms = org_hous_df[org_hous_df['bathrooms'] == 0]['price']
bathroom_pvalue = stats.ttest_ind(no_bedrooms, no_bathrooms)[1]
bathroom_pvalue
# Out:
# 0.6824544554785027

# %% [markdown]
# ## Step 2: Exploratory Data Analysis
#
# Become familiar with the data.  Look to see if there are any extreme values.
#
# Additionally create data visualizations to determine if there are any relationships between your features and your target variables.

# %%
org_hous_df.describe()
# Out:
#            price  bedrooms  bathrooms  sqft_living   sqft_lot   floors  \
# count   17290.00  17290.00   17290.00     17290.00   17290.00 17290.00
# mean   540739.55      3.37       2.11      2081.46   15243.40     1.49
# std    373318.98      0.94       0.77       920.02   42304.62     0.54
# min     75000.00      0.00       0.00       290.00     572.00     1.00
# 25%    321000.00      3.00       1.50      1430.00    5081.25     1.00
# 50%    450000.00      3.00       2.25      1920.00    7642.00     1.50
# 75%    645000.00      4.00       2.50      2550.00   10725.75     2.00
# max   7700000.00     33.00       8.00     13540.00 1651359.00     3.50
#
#        waterfront     view  condition    grade  sqft_above  sqft_basement  \
# count    17290.00 17290.00   17290.00 17290.00    17290.00       17290.00
# mean         0.01     0.24       3.41     7.65     1789.31         292.16
# std          0.09     0.78       0.65     1.17      829.27         443.15
# min          0.00     0.00       1.00     1.00      290.00           0.00
# 25%          0.00     0.00       3.00     7.00     1200.00           0.00
# 50%          0.00     0.00       3.00     7.00     1560.00           0.00
# 75%          0.00     0.00       4.00     8.00     2214.50         560.00
# max          1.00     4.00       5.00    13.00     9410.00        4820.00
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# count  17290.00      17290.00 17290.00 17290.00 17290.00       17290.00
# mean    1970.79         83.81 98078.19    47.56  -122.21        1987.99
# std       29.34        400.33    53.61     0.14     0.14         684.80
# min     1900.00          0.00 98001.00    47.16  -122.52         399.00
# 25%     1951.00          0.00 98033.00    47.47  -122.33        1490.00
# 50%     1974.00          0.00 98065.00    47.57  -122.23        1840.00
# 75%     1996.00          0.00 98118.00    47.68  -122.13        2360.00
# max     2015.00       2015.00 98199.00    47.78  -121.31        6210.00
#
#        sqft_lot15
# count    17290.00
# mean     12873.48
# std      27227.44
# min        659.00
# 25%       5111.25
# 50%       7622.50
# 75%      10101.75
# max     858132.00

# %%
#Identify colinearity for all features with price with plots
fig, axes = plt.subplots(6, 3, figsize=(20,30), sharey=True)
for ax, column in zip(axes.flatten(), org_hous_df.columns[2:]):
    ax.scatter(org_hous_df[column], org_hous_df['price'], label=column, alpha=.05)
    ax.set_title(f'Price vs {column}')
    ax.set_xlabel(column)
    ax.set_ylabel('Price')

# %%
org_hous_df.groupby("view")["price"].mean().plot(kind='bar', figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='view'>

# %%
corr = org_hous_df.corr().abs()
sns.set(rc={'figure.figsize':(12,9)})
sns.heatmap(corr[:20], xticklabels=corr[:20].columns, \
            yticklabels=corr[:20].columns, \
            annot=False, cmap='Blues_r', center= 0)
plt.title('Degrees of Correlation in dataset');

# %%
sns.set_palette('Blues_r')
x = ['98039', '98004', '98040', '98112', '98102']
y = [2.202790e+06, 1.396883e+06, 1.183018e+06, 1.119458e+06, 9.336715e+05]
fig, ax = plt.subplots(figsize = (15, 5))
ax = sns.barplot(x=x,y=y, data=org_hous_df)
ax.ticklabel_format(style='scientific', axis='y')

ax.set(xlabel='Zip Code', ylabel='Avg. Price')
plt.title("Average Home Price")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (12,6))
sns.distplot(org_hous_df['price'], bins=50, color = 'b')
ax.set(xlim=[0, 5000000], xlabel='Sale Price', ylabel='Sale Count',
       title='Sale Distribution')
# Out:
# [(0.0, 5000000.0),
#  Text(0.5, 0, 'Sale Price'),
#  Text(0, 0.5, 'Sale Count'),
#  Text(0.5, 1.0, 'Sale Distribution')]

# %%
sns.set_theme(style='ticks', palette="rocket")
org_hous_df.hist(bins=50, figsize=(20,20))
plt.show()

# %%
var = 'waterfront'
data = pd.concat([org_hous_df['price'], org_hous_df[var]], axis=1)
fig, ax = plt.subplots(figsize=(10,8))
fig = sns.boxplot(x=var, y='price', data=data)

# %%
sns.scatterplot(data = org_hous_df, x = org_hous_df['price'], y = org_hous_df['sqft_living'])

plt.show()

# %%
#folium Map using coordinates
kc_map = folium.Map(location = [47.5480, -121.9836], tiles = 'OpenStreetMap', zoom_start = 9)

kc_coord = list(zip(org_hous_df['lat'], org_hous_df['long']))

for coord in kc_coord:
    folium.Marker(location = coord).add_to(kc_map)

#kc_map

# %% [markdown]
# ## Step 3: Clean up any issues (extreme values, etc.) with the data.
#
# Remember that you can't just delete rows with extreme values. Similar observations might be present in the holdout data set, and you can't just delete those rows and not have a prediction for it.

# %% [markdown]
# bedrooms - 33 bedroom house on Google Maps seems to be typo for a 3 bedroom house, twelve "studios" with no bedrooms
# bathrooms - eight with no bathrooms

# %%
#correct 33 bedroom home
org_hous_df['bedrooms'].replace(33, 3, inplace=True)

# %% [markdown]
# ## Step 4: Generate new features that you think could be important.
#
# After doing this, you will want to go back to steps 2 and 3 to investigate these new features.

# %%
#yard_space column
org_hous_df['yard_space'] = org_hous_df.sqft_lot - (org_hous_df.sqft_living / org_hous_df.floors)

# %%
#multi_floor_column
org_hous_df['multi_floor'] = [0 if x == 1 else 1 for x in org_hous_df.floors]

# %%
#Basement coulumn
org_hous_df['has_basement'] = [0 if x == 0 else 1 for x in org_hous_df.sqft_basement]

# %%
#sale_month column to explore affeect of seasons
org_hous_df['sale_month'] = pd.DatetimeIndex(org_hous_df['date']).month

# %%
#Year Renovated coulumn
org_hous_df['yr_built_reno'] = np.where((org_hous_df['yr_built'] < 1974) & (org_hous_df['yr_renovated'] == 0), 0,1)

# %%
org_hous_df
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 2591820310  20141006T000000  365000.00         4       2.25         2070
# 7974200820  20140821T000000  865000.00         5       3.00         2900
# 7701450110  20140815T000000 1038000.00         4       2.50         3770
# 9522300010  20150331T000000 1490000.00         3       3.50         4560
# 9510861140  20140714T000000  711000.00         3       2.50         2550
# ...                     ...        ...       ...        ...          ...
# 627300195   20150303T000000  750000.00         5       2.50         3240
# 8819900270  20140520T000000  440000.00         2       1.75         1300
# 3816300095  20140514T000000  310000.00         3       1.00         1050
# 122069107   20141204T000000  427500.00         3       1.50         1900
# 6703100135  20150116T000000  348000.00         3       1.50         1330
#
#             sqft_lot  floors  waterfront  view  condition  ...  zipcode   lat  \
# id                                                         ...
# 2591820310      8893    2.00           0     0          4  ...    98058 47.44
# 7974200820      6730    1.00           0     0          5  ...    98115 47.68
# 7701450110     10893    2.00           0     2          3  ...    98006 47.56
# 9522300010     14608    2.00           0     2          3  ...    98034 47.70
# 9510861140      5376    2.00           0     0          3  ...    98052 47.66
# ...              ...     ...         ...   ...        ...  ...      ...   ...
# 627300195       9960    1.00           0     1          3  ...    98008 47.59
# 8819900270      4000    2.00           0     0          3  ...    98105 47.67
# 3816300095      9876    1.00           0     0          3  ...    98028 47.76
# 122069107      43186    1.50           0     0          4  ...    98038 47.42
# 6703100135      6768    1.00           0     0          4  ...    98155 47.74
#
#               long  sqft_living15  sqft_lot15  yard_space  multi_floor  \
# id
# 2591820310 -122.16           2390        7700     7858.00            1
# 7974200820 -122.28           2370        6283     3830.00            0
# 7701450110 -122.13           3710        9685     9008.00            1
# 9522300010 -122.23           4050       14226    12328.00            1
# 9510861140 -122.08           2250        4050     4101.00            1
# ...            ...            ...         ...         ...          ...
# 627300195  -122.11           2730       10400     6720.00            0
# 8819900270 -122.29           1350        4013     3350.00            1
# 3816300095 -122.26           1760        9403     8826.00            0
# 122069107  -121.99           2080      108028    41919.33            1
# 6703100135 -122.32           1320        6910     5438.00            0
#
#             has_basement  sale_month  yr_built_reno
# id
# 2591820310             0          10              1
# 7974200820             1           8              1
# 7701450110             0           8              1
# 9522300010             0           3              1
# 9510861140             0           7              1
# ...                  ...         ...            ...
# 627300195              1           3              0
# 8819900270             0           5              0
# 3816300095             0           5              0
# 122069107              1          12              0
# 6703100135             0           1              0
#
# [17290 rows x 25 columns]

# %% [markdown]
# ### 4.1) Identify a categorical variable in the data set and create dummy columns.

# %%
# identified zipcode,grade and view
org_hous_df=pd.get_dummies(org_hous_df, columns=['zipcode'], drop_first=True)
org_hous_df=pd.get_dummies(org_hous_df, columns=['grade'], drop_first=True)
org_hous_df=pd.get_dummies(org_hous_df, columns=['view'], drop_first=True)
#sqft of homes sold with the best view
org_hous_df['bestview_sqftliving'] = org_hous_df['view_4']*org_hous_df['sqft_living']
#zipcode with 474 houses sqft
org_hous_df['biggestzipcode_sqftliving'] = org_hous_df['zipcode_98052']*org_hous_df['sqft_living']
org_hous_df.shape
# Out:
# (17290, 108)

# %% [markdown]
# ### 4.3) There are columns for when the house was built and when it was renovated.  How could you use these columns to create a new column?

# %%
org_hous_df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'condition', 'sqft_above',
#        ...
#        'grade_10', 'grade_11', 'grade_12', 'grade_13', 'view_1', 'view_2',
#        'view_3', 'view_4', 'bestview_sqftliving', 'biggestzipcode_sqftliving'],
#       dtype='object', length=108)

# %%
ols(formula='price~sqft_living', data= org_hous_df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.495
# Model:                            OLS   Adj. R-squared:                  0.495
# Method:                 Least Squares   F-statistic:                 1.694e+04
# Date:                Sat, 05 Jun 2021   Prob (F-statistic):               0.00
# Time:                        14:49:06   Log-Likelihood:            -2.4046e+05
# No. Observations:               17290   AIC:                         4.809e+05
# Df Residuals:                   17288   BIC:                         4.809e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -5.347e+04   4991.006    -10.714      0.000   -6.33e+04   -4.37e+04
# sqft_living   285.4779      2.193    130.167      0.000     281.179     289.777
# ==============================================================================
# Omnibus:                    12367.474   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           507839.480
# Skew:                           2.968   Prob(JB):                         0.00
# Kurtosis:                      28.878   Cond. No.                     5.63e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.63e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### <ins>Non-linear transformations</ins>
#
# ### 4.4) Create a polynomial feature for two of your continuous variables.

# %%
org_hous_df['sqft_living^3'] = org_hous_df['sqft_living']**3
org_hous_df['sqft_living^2'] = org_hous_df['sqft_living']**2
org_hous_df['sqft_basement^2'] = org_hous_df['sqft_basement']**2
org_hous_df
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 2591820310  20141006T000000  365000.00         4       2.25         2070
# 7974200820  20140821T000000  865000.00         5       3.00         2900
# 7701450110  20140815T000000 1038000.00         4       2.50         3770
# 9522300010  20150331T000000 1490000.00         3       3.50         4560
# 9510861140  20140714T000000  711000.00         3       2.50         2550
# ...                     ...        ...       ...        ...          ...
# 627300195   20150303T000000  750000.00         5       2.50         3240
# 8819900270  20140520T000000  440000.00         2       1.75         1300
# 3816300095  20140514T000000  310000.00         3       1.00         1050
# 122069107   20141204T000000  427500.00         3       1.50         1900
# 6703100135  20150116T000000  348000.00         3       1.50         1330
#
#             sqft_lot  floors  waterfront  condition  sqft_above  ...  \
# id                                                               ...
# 2591820310      8893    2.00           0          4        2070  ...
# 7974200820      6730    1.00           0          5        1830  ...
# 7701450110     10893    2.00           0          3        3770  ...
# 9522300010     14608    2.00           0          3        4560  ...
# 9510861140      5376    2.00           0          3        2550  ...
# ...              ...     ...         ...        ...         ...  ...
# 627300195       9960    1.00           0          3        2020  ...
# 8819900270      4000    2.00           0          3        1300  ...
# 3816300095      9876    1.00           0          3        1050  ...
# 122069107      43186    1.50           0          4        1300  ...
# 6703100135      6768    1.00           0          4        1330  ...
#
#             grade_13  view_1  view_2  view_3  view_4  bestview_sqftliving  \
# id
# 2591820310         0       0       0       0       0                    0
# 7974200820         0       0       0       0       0                    0
# 7701450110         0       0       1       0       0                    0
# 9522300010         0       0       1       0       0                    0
# 9510861140         0       0       0       0       0                    0
# ...              ...     ...     ...     ...     ...                  ...
# 627300195          0       1       0       0       0                    0
# 8819900270         0       0       0       0       0                    0
# 3816300095         0       0       0       0       0                    0
# 122069107          0       0       0       0       0                    0
# 6703100135         0       0       0       0       0                    0
#
#             biggestzipcode_sqftliving  sqft_living^3  sqft_living^2  \
# id
# 2591820310                          0     8869743000        4284900
# 7974200820                          0    24389000000        8410000
# 7701450110                          0    53582633000       14212900
# 9522300010                          0    94818816000       20793600
# 9510861140                       2550    16581375000        6502500
# ...                               ...            ...            ...
# 627300195                           0    34012224000       10497600
# 8819900270                          0     2197000000        1690000
# 3816300095                          0     1157625000        1102500
# 122069107                           0     6859000000        3610000
# 6703100135                          0     2352637000        1768900
#
#             sqft_basement^2
# id
# 2591820310                0
# 7974200820          1144900
# 7701450110                0
# 9522300010                0
# 9510861140                0
# ...                     ...
# 627300195           1488400
# 8819900270                0
# 3816300095                0
# 122069107            360000
# 6703100135                0
#
# [17290 rows x 111 columns]

# %% [markdown]
# ### 4.5) Create an interaction feature between a binary variable (dummy variable) and a continuous variable.

# %%
continuous = ['sqft_living','sqft_lot','sqft_above','sqft_basement','yr_built','sqft_living15','sqft_lot15']

for column in continuous:
    sns.jointplot(x=column, y="price", data=org_hous_df, kind='reg', label=column,joint_kws={'line_kws':{'color':'red'}})
    plt.legend()
    plt.show()

# %% [markdown]
# ### 4.6) SKLearn Identifying Features

# %%
#save cleaned df
org_hous_df.to_csv('~/Data', index=0)
org_hous_df
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 2591820310  20141006T000000  365000.00         4       2.25         2070
# 7974200820  20140821T000000  865000.00         5       3.00         2900
# 7701450110  20140815T000000 1038000.00         4       2.50         3770
# 9522300010  20150331T000000 1490000.00         3       3.50         4560
# 9510861140  20140714T000000  711000.00         3       2.50         2550
# ...                     ...        ...       ...        ...          ...
# 627300195   20150303T000000  750000.00         5       2.50         3240
# 8819900270  20140520T000000  440000.00         2       1.75         1300
# 3816300095  20140514T000000  310000.00         3       1.00         1050
# 122069107   20141204T000000  427500.00         3       1.50         1900
# 6703100135  20150116T000000  348000.00         3       1.50         1330
#
#             sqft_lot  floors  waterfront  condition  sqft_above  ...  \
# id                                                               ...
# 2591820310      8893    2.00           0          4        2070  ...
# 7974200820      6730    1.00           0          5        1830  ...
# 7701450110     10893    2.00           0          3        3770  ...
# 9522300010     14608    2.00           0          3        4560  ...
# 9510861140      5376    2.00           0          3        2550  ...
# ...              ...     ...         ...        ...         ...  ...
# 627300195       9960    1.00           0          3        2020  ...
# 8819900270      4000    2.00           0          3        1300  ...
# 3816300095      9876    1.00           0          3        1050  ...
# 122069107      43186    1.50           0          4        1300  ...
# 6703100135      6768    1.00           0          4        1330  ...
#
#             grade_13  view_1  view_2  view_3  view_4  bestview_sqftliving  \
# id
# 2591820310         0       0       0       0       0                    0
# 7974200820         0       0       0       0       0                    0
# 7701450110         0       0       1       0       0                    0
# 9522300010         0       0       1       0       0                    0
# 9510861140         0       0       0       0       0                    0
# ...              ...     ...     ...     ...     ...                  ...
# 627300195          0       1       0       0       0                    0
# 8819900270         0       0       0       0       0                    0
# 3816300095         0       0       0       0       0                    0
# 122069107          0       0       0       0       0                    0
# 6703100135         0       0       0       0       0                    0
#
#             biggestzipcode_sqftliving  sqft_living^3  sqft_living^2  \
# id
# 2591820310                          0     8869743000        4284900
# 7974200820                          0    24389000000        8410000
# 7701450110                          0    53582633000       14212900
# 9522300010                          0    94818816000       20793600
# 9510861140                       2550    16581375000        6502500
# ...                               ...            ...            ...
# 627300195                           0    34012224000       10497600
# 8819900270                          0     2197000000        1690000
# 3816300095                          0     1157625000        1102500
# 122069107                           0     6859000000        3610000
# 6703100135                          0     2352637000        1768900
#
#             sqft_basement^2
# id
# 2591820310                0
# 7974200820          1144900
# 7701450110                0
# 9522300010                0
# 9510861140                0
# ...                     ...
# 627300195           1488400
# 8819900270                0
# 3816300095                0
# 122069107            360000
# 6703100135                0
#
# [17290 rows x 111 columns]

# %%
df_features = org_hous_df.filter(org_hous_df.columns)
df_features.drop(columns=['lat','long','date','price'], inplace=True)

# %%
target = org_hous_df['price']

# %%
len(df_features.columns)
# Out:
# 107

# %%
df_features.shape
# Out:
# (17290, 107)

# %%
from sklearn.linear_model import LinearRegression

#instantiate a linear regression object
lm = LinearRegression()

#fit the linear regression to the data
lm = lm.fit(df_features, target)

#access output
print(lm.intercept_)
print(lm.coef_)
print("R^2: ", lm.score(df_features, target))
# Out:
# 351680.85624963883
# [-5.48207374e+03  2.79307078e+04  4.59223440e+01 -8.91280885e+00
#  -3.95283864e+04  5.90946283e+05  3.34991915e+04 -2.92731901e+01
#  -1.58879416e+01 -2.00454552e+02  3.31014225e+01  3.02918126e+01
#  -7.28043698e-02  9.10259765e+00  1.11876497e+04 -1.37851491e+04
#  -2.67751275e+03 -8.75198905e+03  4.82488444e+03 -1.12730996e+04
#   7.67589044e+05  2.97530349e+05  2.42213504e+05  2.48321251e+05
#   2.51838577e+05  5.95563168e+04  1.38300401e+05  9.98640291e+04
#   9.53898937e+04 -6.33029160e+03 -3.22496412e+04  1.55723269e+05
#   1.61216185e+05  1.32581100e+05  2.13833340e+05  4.50909819e+03
#   1.31022969e+04  1.46933983e+03  3.52101106e+05  1.99394854e+05
#   3.60516164e+04  1.17906398e+06  4.78509304e+05  6.13651321e+03
#   9.71315875e+04  2.93255953e+05  1.98166973e+05  4.06746138e+04
#   8.83289483e+04  3.22528096e+04  7.93249459e+04  8.84523486e+04
#   2.72158883e+04  1.60130017e+05  1.79010917e+05  1.65437824e+05
#   1.05724383e+05 -2.59869683e+04  4.82021684e+05  3.41663206e+05
#   4.69845891e+05  1.17513077e+05  3.41128662e+05  1.19852652e+05
#   5.02723059e+05  6.32312047e+05  3.29072281e+05  2.92155960e+05
#   3.16294631e+05  1.60485252e+05  5.02032359e+05  3.33787656e+05
#   1.96479110e+05  1.87635566e+05  1.58094856e+05  2.52948408e+05
#   2.82103433e+05  9.59622688e+04  5.80174105e+04  1.42415450e+05
#   5.47800747e+04  5.06150226e+04  2.16977759e+05  3.20815967e+04
#   3.31121043e+04 -1.51545410e+03  3.84371273e+05  6.22964688e+04
#   2.35117390e+04  5.46544760e+03  2.02071102e+04  4.53314582e+04
#   8.48068351e+04  1.56947714e+05  2.63710169e+05  4.03823933e+05
#   6.89387565e+05  1.67685744e+06  7.97353811e+04  7.18655110e+04
#   1.38289976e+05 -1.82019717e+04  9.02653004e+01 -2.29780805e+01
#  -9.43389750e-07  3.03314422e-02 -3.75553554e-02]
# R^2:  0.844123962957097

# %%
from sklearn.preprocessing import PolynomialFeatures

#poly = PolynomialFeatures(degree=2, include_bias=False)

# %%
#poly_data = poly.fit_transform(df_features)

# %%
df_features.isnull().value_counts
# Out:
# <bound method DataFrame.value_counts of             bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# id
# 2591820310     False      False        False     False   False       False
# 7974200820     False      False        False     False   False       False
# 7701450110     False      False        False     False   False       False
# 9522300010     False      False        False     False   False       False
# 9510861140     False      False        False     False   False       False
# ...              ...        ...          ...       ...     ...         ...
# 627300195      False      False        False     False   False       False
# 8819900270     False      False        False     False   False       False
# 3816300095     False      False        False     False   False       False
# 122069107      False      False        False     False   False       False
# 6703100135     False      False        False     False   False       False
#
#             condition  sqft_above  sqft_basement  yr_built  ...  grade_13  \
# id                                                          ...
# 2591820310      False       False          False     False  ...     False
# 7974200820      False       False          False     False  ...     False
# 7701450110      False       False          False     False  ...     False
# 9522300010      False       False          False     False  ...     False
# 9510861140      False       False          False     False  ...     False
# ...               ...         ...            ...       ...  ...       ...
# 627300195       False       False          False     False  ...     False
# 8819900270      False       False          False     False  ...     False
# 3816300095      False       False          False     False  ...     False
# 122069107       False       False          False     False  ...     False
# 6703100135      False       False          False     False  ...     False
#
#             view_1  view_2  view_3  view_4  bestview_sqftliving  \
# id
# 2591820310   False   False   False   False                False
# 7974200820   False   False   False   False                False
# 7701450110   False   False   False   False                False
# 9522300010   False   False   False   False                False
# 9510861140   False   False   False   False                False
# ...            ...     ...     ...     ...                  ...
# 627300195    False   False   False   False                False
# 8819900270   False   False   False   False                False
# 3816300095   False   False   False   False                False
# 122069107    False   False   False   False                False
# 6703100135   False   False   False   False                False
#
#             biggestzipcode_sqftliving  sqft_living^3  sqft_living^2  \
# id
# 2591820310                      False          False          False
# 7974200820                      False          False          False
# 7701450110                      False          False          False
# 9522300010                      False          False          False
# 9510861140                      False          False          False
# ...                               ...            ...            ...
# 627300195                       False          False          False
# 8819900270                      False          False          False
# 3816300095                      False          False          False
# 122069107                       False          False          False
# 6703100135                      False          False          False
#
#             sqft_basement^2
# id
# 2591820310            False
# 7974200820            False
# 7701450110            False
# 9522300010            False
# 9510861140            False
# ...                     ...
# 627300195             False
# 8819900270            False
# 3816300095            False
# 122069107             False
# 6703100135            False
#
# [17290 rows x 107 columns]>

# %% [markdown]
# ## Step 5: Model Evaluation

# %% [markdown]
# ## 5.1)  Fit an initial model and check the errors to see if the model assumptions are being met. If need be, go back to steps 3 and 4 to improve your model.

# %%
ols(formula='price~C(zipcode)+C(grade)+C(view)+sqft_living', data=df_features).fit().summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# /opt/anaconda3/lib/python3.8/site-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     164         code = compile(expr, source_name, "eval", self.flags, False)
# --> 165         return eval(code, {}, VarLookupDict([inner_namespace]
#     166                                             + self._namespaces))
#
# <string> in <module>
#
# NameError: name 'zipcode' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-49-4fdd46f68124> in <module>
# ----> 1 ols(formula='price~C(zipcode)+C(grade)+C(view)+sqft_living', data=df_features).fit().summary()
#
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     167             missing = 'raise'
#     168
# --> 169         tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     170                                   missing=missing)
#     171         ((endog, exog), missing_idx, design_info) = tmp
#
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      61     else:
#      62         if data_util._is_using_pandas(Y, None):
# ---> 63             result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                                NA_action=na_action)
#      65         else:
#
# /opt/anaconda3/lib/python3.8/site-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     307     """
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#
# /opt/anaconda3/lib/python3.8/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     162     def data_iter_maker():
#     163         return iter([data])
# --> 164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                       NA_action)
#     166     if design_infos is not None:
#
# /opt/anaconda3/lib/python3.8/site-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      64     if isinstance(formula_like, ModelDesc):
#      65         assert isinstance(eval_env, EvalEnvironment)
# ---> 66         return design_matrix_builders([formula_like.lhs_termlist,
#      67                                        formula_like.rhs_termlist],
#      68                                       data_iter_maker,
#
# /opt/anaconda3/lib/python3.8/site-packages/patsy/build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     691     # on some data to find out what type of data they return.
#     692     (num_column_counts,
# --> 693      cat_levels_contrasts) = _examine_factor_types(all_factors,
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
#
# /opt/anaconda3/lib/python3.8/site-packages/patsy/build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# /opt/anaconda3/lib/python3.8/site-packages/patsy/eval.py in eval(self, memorize_state, data)
#     562
#     563     def eval(self, memorize_state, data):
# --> 564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
#     566                           data)
#
# /opt/anaconda3/lib/python3.8/site-packages/patsy/eval.py in _eval(self, code, memorize_state, data)
#     545     def _eval(self, code, memorize_state, data):
#     546         inner_namespace = VarLookupDict([data, memorize_state["transforms"]])
# --> 547         return call_and_wrap_exc("Error evaluating factor",
#     548                                  self,
#     549                                  memorize_state["eval_env"].eval,
#
# /opt/anaconda3/lib/python3.8/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      41                                  origin)
#      42             # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43             exec("raise new_exc from e")
#      44         else:
#      45             # In python 2, we just let the original exception escape -- better
#
# /opt/anaconda3/lib/python3.8/site-packages/patsy/compat.py in <module>
#
# PatsyError: Error evaluating factor: NameError: name 'zipcode' is not defined
#     price~C(zipcode)+C(grade)+C(view)+sqft_living
#           ^^^^^^^^^^

# %%
df_features
# Out:
#             bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# id
# 2591820310         4       2.25         2070      8893    2.00           0
# 7974200820         5       3.00         2900      6730    1.00           0
# 7701450110         4       2.50         3770     10893    2.00           0
# 9522300010         3       3.50         4560     14608    2.00           0
# 9510861140         3       2.50         2550      5376    2.00           0
# ...              ...        ...          ...       ...     ...         ...
# 627300195          5       2.50         3240      9960    1.00           0
# 8819900270         2       1.75         1300      4000    2.00           0
# 3816300095         3       1.00         1050      9876    1.00           0
# 122069107          3       1.50         1900     43186    1.50           0
# 6703100135         3       1.50         1330      6768    1.00           0
#
#             condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# id
# 2591820310          4        2070              0      1986             0
# 7974200820          5        1830           1070      1977             0
# 7701450110          3        3770              0      1997             0
# 9522300010          3        4560              0      1990             0
# 9510861140          3        2550              0      2004             0
# ...               ...         ...            ...       ...           ...
# 627300195           3        2020           1220      1958             0
# 8819900270          3        1300              0      1948             0
# 3816300095          3        1050              0      1953             0
# 122069107           4        1300            600      1971             0
# 6703100135          4        1330              0      1952             0
#
#             sqft_living15  sqft_lot15  yard_space  multi_floor  has_basement  \
# id
# 2591820310           2390        7700     7858.00            1             0
# 7974200820           2370        6283     3830.00            0             1
# 7701450110           3710        9685     9008.00            1             0
# 9522300010           4050       14226    12328.00            1             0
# 9510861140           2250        4050     4101.00            1             0
# ...                   ...         ...         ...          ...           ...
# 627300195            2730       10400     6720.00            0             1
# 8819900270           1350        4013     3350.00            1             0
# 3816300095           1760        9403     8826.00            0             0
# 122069107            2080      108028    41919.33            1             1
# 6703100135           1320        6910     5438.00            0             0
#
#             sale_month  yr_built_reno  zipcode_98002  zipcode_98003  \
# id
# 2591820310          10              1              0              0
# 7974200820           8              1              0              0
# 7701450110           8              1              0              0
# 9522300010           3              1              0              0
# 9510861140           7              1              0              0
# ...                ...            ...            ...            ...
# 627300195            3              0              0              0
# 8819900270           5              0              0              0
# 3816300095           5              0              0              0
# 122069107           12              0              0              0
# 6703100135           1              0              0              0
#
#             zipcode_98004  zipcode_98005  zipcode_98006  zipcode_98007  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              1              0
# 9522300010              0              0              0              0
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              0              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98008  zipcode_98010  zipcode_98011  zipcode_98014  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              0
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               1              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              0              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98019  zipcode_98022  zipcode_98023  zipcode_98024  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              0
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              0              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98027  zipcode_98028  zipcode_98029  zipcode_98030  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              0
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              1              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98031  zipcode_98032  zipcode_98033  zipcode_98034  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              1
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              0              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98038  zipcode_98039  zipcode_98040  zipcode_98042  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              0
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              0              0              0
# 122069107               1              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98045  zipcode_98052  zipcode_98053  zipcode_98055  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              0
# 9510861140              0              1              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              0              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98056  zipcode_98058  zipcode_98059  zipcode_98065  \
# id
# 2591820310              0              1              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              0
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              0              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98070  zipcode_98072  zipcode_98074  zipcode_98075  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              0
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              0              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98077  zipcode_98092  zipcode_98102  zipcode_98103  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              0
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              0              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98105  zipcode_98106  zipcode_98107  zipcode_98108  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              0
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              1              0              0              0
# 3816300095              0              0              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98109  zipcode_98112  zipcode_98115  zipcode_98116  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              1              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              0
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              0              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98117  zipcode_98118  zipcode_98119  zipcode_98122  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              0
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              0              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98125  zipcode_98126  zipcode_98133  zipcode_98136  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              0
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              0              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98144  zipcode_98146  zipcode_98148  zipcode_98155  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              0
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              0              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              1
#
#             zipcode_98166  zipcode_98168  zipcode_98177  zipcode_98178  \
# id
# 2591820310              0              0              0              0
# 7974200820              0              0              0              0
# 7701450110              0              0              0              0
# 9522300010              0              0              0              0
# 9510861140              0              0              0              0
# ...                   ...            ...            ...            ...
# 627300195               0              0              0              0
# 8819900270              0              0              0              0
# 3816300095              0              0              0              0
# 122069107               0              0              0              0
# 6703100135              0              0              0              0
#
#             zipcode_98188  zipcode_98198  zipcode_98199  grade_3  grade_4  \
# id
# 2591820310              0              0              0        0        0
# 7974200820              0              0              0        0        0
# 7701450110              0              0              0        0        0
# 9522300010              0              0              0        0        0
# 9510861140              0              0              0        0        0
# ...                   ...            ...            ...      ...      ...
# 627300195               0              0              0        0        0
# 8819900270              0              0              0        0        0
# 3816300095              0              0              0        0        0
# 122069107               0              0              0        0        0
# 6703100135              0              0              0        0        0
#
#             grade_5  grade_6  grade_7  grade_8  grade_9  grade_10  grade_11  \
# id
# 2591820310        0        0        0        1        0         0         0
# 7974200820        0        0        0        1        0         0         0
# 7701450110        0        0        0        0        0         0         1
# 9522300010        0        0        0        0        0         0         0
# 9510861140        0        0        0        0        1         0         0
# ...             ...      ...      ...      ...      ...       ...       ...
# 627300195         0        0        0        1        0         0         0
# 8819900270        0        0        1        0        0         0         0
# 3816300095        0        0        1        0        0         0         0
# 122069107         0        0        1        0        0         0         0
# 6703100135        0        0        1        0        0         0         0
#
#             grade_12  grade_13  view_1  view_2  view_3  view_4  \
# id
# 2591820310         0         0       0       0       0       0
# 7974200820         0         0       0       0       0       0
# 7701450110         0         0       0       1       0       0
# 9522300010         1         0       0       1       0       0
# 9510861140         0         0       0       0       0       0
# ...              ...       ...     ...     ...     ...     ...
# 627300195          0         0       1       0       0       0
# 8819900270         0         0       0       0       0       0
# 3816300095         0         0       0       0       0       0
# 122069107          0         0       0       0       0       0
# 6703100135         0         0       0       0       0       0
#
#             bestview_sqftliving  biggestzipcode_sqftliving  sqft_living^3  \
# id
# 2591820310                    0                          0     8869743000
# 7974200820                    0                          0    24389000000
# 7701450110                    0                          0    53582633000
# 9522300010                    0                          0    94818816000
# 9510861140                    0                       2550    16581375000
# ...                         ...                        ...            ...
# 627300195                     0                          0    34012224000
# 8819900270                    0                          0     2197000000
# 3816300095                    0                          0     1157625000
# 122069107                     0                          0     6859000000
# 6703100135                    0                          0     2352637000
#
#             sqft_living^2  sqft_basement^2
# id
# 2591820310        4284900                0
# 7974200820        8410000          1144900
# 7701450110       14212900                0
# 9522300010       20793600                0
# 9510861140        6502500                0
# ...                   ...              ...
# 627300195        10497600          1488400
# 8819900270        1690000                0
# 3816300095        1102500                0
# 122069107         3610000           360000
# 6703100135        1768900                0
#
# [17290 rows x 107 columns]

# %%
poly_columns = poly.get_feature_names(df_features.columns)

# %%
len(poly_columns)

# %%
df_features

# %%
df_poly = pd.DataFrame(poly_data, columns=poly_columns)

# %%
df_poly.head()

# %%
poly_3 = PolynomialFeatures(degree=3, include_bias=False)
poly3_data = poly_3.fit_transform(df_features)
poly3_columns = poly_3.get_feature_names(df_features.columns)
df_poly3 = pd.DataFrame(poly3_data, columns=poly3_columns)

# %%
#instantiate a linear regression object
lm_2 = LinearRegression()

#fit the linear regression to the data
lm_2 = lm_2.fit(df_poly, target)

#access output
print(lm_2.intercept_)
print(lm_2.coef_)
print("R^2: ", lm_2.score(df_poly, target))

# %%
#instantiate a linear regression object
lm_3 = LinearRegression()

#fit the linear regression to the data
lm_3 = lm_3.fit(df_poly3, target)

#access output
# print(lm_3.intercept_)
# print(lm_3.coef_)
print("R^2: ", lm_3.score(df_poly3, target))

# %%
df_features.columns

# %% [markdown]
# ### 5.2) Perform a train-test split of the data.

# %%
X_train, X_test, y_train, y_test = train_test_split(df_features, target, random_state=9,test_size=0.3)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_features, target, test_size=0.3, random_state=34)
print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-1491e3005897> in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(df_features, target, test_size=0.3, random_state=34)
#       2 print(len(X_train), len(X_test), len(y_train), len(y_test))
#
# NameError: name 'target' is not defined

# %% [markdown]
# ### 5.3) Fit the model to the training data.

# %%
y_train

# %%
target.head()

# %%
scaler = StandardScaler()

# fit the scaler to the training data
scaler.fit(X_train)

#transform the training data
scaled_data = scaler.transform(X_train)

#create dataframe
X_train = pd.DataFrame(data=scaled_data, columns=df_features.columns)

#transform the testing dat
X_test = pd.DataFrame(data=scaler.transform(X_test), columns=df_features.columns)

# %% [markdown]
# ### 5.4) Use the model to predict on the training set and the test set.

# %%
#check the shape of the results
print("Training set - Features: ", X_train.shape, "Target: ", y_train.shape)
print("Training set - Features: ", X_test.shape, "Target: ",y_test.shape)

# %% [markdown]
# ### 5.5) Evaluate the training and test predictions using RMSE.

# %% [markdown]
# ### 5.6) Determine if your model is overfit.

# %%
def test_data(df_features, target):
    testtrainsplit
    lm = LinearRegression()
    lm.fit()
    return RMSE

# %%
df1_rmse = test_data(org_hous_df)

# %% [markdown]
# ## Step 6: Utilize some different feature selection techniques before or in conjuction with fitting your models. You will have to repeat steps 5.3 through 5.6 to determine how your new model is performing.

# %% [markdown]
# ### 6.1) Utilize a filter method to identify some features to remove from the model.

# %%
X_train.shape

# %%
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression

selector = SelectKBest(f_regression, k='all')

selector.fit(X_train, y_train)

# %%
selector.get_support()

# %%
selected_columns = X_train.columns[selector.get_support()]
removed_columns = X_train.columns[~selector.get_support()]
X_train = X_train[selected_columns]
X_test = X_test[selected_columns]

# %%
list(selected_columns)

# %% [markdown]
# ### 6.2) After removing the features, re-run Step 5 and see if your new model performs better than the old model.

# %%
sns.set(style="white")


# Compute the correlation matrix
corr = X_train.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df_features.shape

# %%
target.shape

# %%
#instantiate a linear regression object
lm_kbest = LinearRegression()

#fit the linear regression to the data
lm_kbest.fit(df_features, target)

y_train_kbest = lm_kbest.predict(df_features)


trainK_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_train_kbest))


print('Training Root Mean Squared Error:' , trainK_rmse)

y_kbest = lm_kbest.predict(X_test)

testK_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_kbest))

print('Testing Root Mean Squared Error:' , testK_rmse)

# %%
import pickle

pickle_out = open("model.pickle","wb")

pickle.dump(lm, pickle_out)

pickle_out.close()

# %%
pickle_out = open("column_selection.pickle","wb")

pickle.dump(df_features.columns, pickle_out)

pickle_out.close()

# %% [markdown]
# ## Step 7: Compare the RMSE of your different models that use different features and determine the best model overall.

# %% [markdown]
# ## Step 8:  Refit your best model to the entire dataset.

# %% [markdown]
# ## Step 9: Save your final model using pickle.
#
# https://machinelearningmastery.com/save-load-machine-learning-models-python-scikit-learn/
